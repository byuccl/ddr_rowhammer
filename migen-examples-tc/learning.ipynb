# %%
from migen import *
from migen.fhdl import verilog
from litex_boards.platforms import digilent_nexys4ddr as board
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /home/tommycox/ddr_rowhammer/migen-examples-tc/learning.ipynb Cell 1' in <cell line: 3>()
#       <a href='vscode-notebook-cell:/home/tommycox/ddr_rowhammer/migen-examples-tc/learning.ipynb#ch0000000?line=0'>1</a> from migen import *
#       <a href='vscode-notebook-cell:/home/tommycox/ddr_rowhammer/migen-examples-tc/learning.ipynb#ch0000000?line=1'>2</a> from migen.fhdl import verilog
# ----> <a href='vscode-notebook-cell:/home/tommycox/ddr_rowhammer/migen-examples-tc/learning.ipynb#ch0000000?line=2'>3</a> from litex_boards.platforms import digilent_nexys4ddr as board
#
# File ~/ddr_rowhammer/litex-boards/litex_boards/platforms/digilent_nexys4ddr.py:7, in <module>
#       <a href='file:///home/tommycox/ddr_rowhammer/litex-boards/litex_boards/platforms/digilent_nexys4ddr.py?line=0'>1</a> #
# ...
